# %%
import pandas as pd

# %% [markdown]
# # 7. Dataframes VI: GroupBy Object

# %% [markdown]
# ## The Fortune 1000 Dataset
#
# - The **Fortune 1000** is a listing of the 1000 largest American companies as ranked by Fortune magazine.
# - The **DataFrame** includes the company's name, sector, industry, and revenues, profits, and employees.

# %%
fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %% [markdown]
# ## 1. The `groupby` Method
#
# - **Grouping** is a way to organize/categorize/group rows based on the values in certain columns.
# - The `groupby` method returns a **DataFrameGroupBy** object. It resembles a group/collection of **DataFrames** in a dictionary-like structure.
# - The **DataFrameGroupBy** object can perform aggregate operations on each group within it.

# %%
# A. Why use .groupby() method?

# example 1: group companies together based on Sector they are in
# Way 1: inconvenient approach

# calculate sum of revenues per sector: 3 steps 
fortune["Sector"] == "Retailing" # create Boolean Series
# Out:
# Rank
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 996     False
# 997     False
# 997     False
# 999     False
# 1000    False
# Name: Sector, Length: 1000, dtype: bool

# %%
fortune[fortune["Sector"] == "Retailing"] # use Boolean Series to subset Df & only retain companies from Retailing Sector
# Out:
#                              Company     Sector                    Industry  \
# Rank
# 1                            Walmart  Retailing       General Merchandisers
# 15                            Costco  Retailing  Specialty Retailers: Other
# 28                        Home Depot  Retailing  Specialty Retailers: Other
# 38                            Target  Retailing       General Merchandisers
# 47                            Lowe’s  Retailing  Specialty Retailers: Other
# ...                              ...        ...                         ...
# 899   Sears Hometown & Outlet Stores  Retailing  Specialty Retailers: Other
# 922                        Outerwall  Retailing  Specialty Retailers: Other
# 937                          hhgregg  Retailing  Specialty Retailers: Other
# 940             Restoration Hardware  Retailing  Specialty Retailers: Other
# 973             99 Cents Only Stores  Retailing  Specialty Retailers: Other
#
#                  Location  Revenue  Profits  Employees
# Rank
# 1         Bentonville, AR   482130    14694    2300000
# 15           Issaquah, WA   116199     2377     161000
# 28            Atlanta, GA    88519     7009     385000
# 38        Minneapolis, MN    73785     3363     341000
# 47        Mooresville, NC    59074     2546     225000
# ...                   ...      ...      ...        ...
# 899   Hoffman Estates, IL     2288      -27       2918
# 922          Bellevue, WA     2195       44       2670
# 937      Indianapolis, IN     2129     -133       4941
# 940      Corte Madera, CA     2109       91       4200
# 973          Commerce, CA     1999     -232      18200
#
# [80 rows x 7 columns]

# %%
fortune[fortune["Sector"] == "Retailing"]["Revenue"].sum() # on this Df, we can subset "Revenue" column to get Series & on this Series we can perform sum() method
# Out:
# 1465076

# %%
# <--> Problem: we have many different sectors! We cannot write a line of code for every Sector

# therefore: Way 2: more convenient approach = use grouby() method: all 21 sectors at one time!
fortune.groupby("Sector")["Revenue"].sum() # simply indicate what column to group on, subset Revenue column, apply sum() method
# Out:
# Sector
# Aerospace & Defense              357940
# Apparel                           95968
# Business Services                272195
# Chemicals                        243897
# Energy                          1517809
# Engineering & Construction       153983
# Financials                      2217159
# Food and Drug Stores             483769
# Food, Beverages & Tobacco        555967
# Health Care                     1614707
# Hotels, Resturants & Leisure     169546
# Household Products               234737
# Industrials                      497581
# Materials                        259145
# Media                            220764
# Motor Vehicles & Parts           482540
# Retailing                       1465076
# Technology                      1377600
# Telecommunications               461834
# Transportation                   408508
# Wholesalers                      444800
# Name: Revenue, dtype: int64

# %%
# B. What is DataFrameGroupBy object?

fortune.groupby("Sector") # gives a DataFrameGroupBy object = a collection of Dataframes in which each Df holds rows for a specific Sector

# %%
len(fortune.groupby("Sector")) # len() function tells us how many unique values there are in Sector column
# Out:
# 21

# %%
fortune.groupby("Sector").size() # .size() method tells us how many rows/instances each group holds
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
fortune.groupby("Sector").first() # we can also extract the first row from each Df within our DataFrameGroupBy object that holds all these Dfs
fortune.groupby("Sector").last() # or the last row
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# Materials                            Schnitzer Steel Industries
# Media                                                    Cenveo
# Motor Vehicles & Parts            Allison Transmission Holdings
# Retailing                                  99 Cents Only Stores
# Technology                                          F5 Networks
# Telecommunications                                      Equinix
# Transportation                Roadrunner Transportation Systems
# Wholesalers                                   BlueLinx Holdings
#
#                                                                 Industry  \
# Sector
# Aerospace & Defense                                Aerospace and Defense
# Apparel                                                          Apparel
# Business Services                                              Education
# Chemicals                                                      Chemicals
# Energy                                       Utilities: Gas and Electric
# Engineering & Construction                                  Homebuilders
# Financials                                              Commercial Banks
# Food and Drug Stores                                Food and Drug Stores
# Food, Beverages & Tobacco                                        Tobacco
# Health Care                     Health Care: Pharmacy and Other Services
# Hotels, Resturants & Leisure                               Food Services
# Household Products                       Household and Personal Products
# Industrials                                         Industrial Machinery
# Materials                                                         Metals
# Media                                               Publishing, Printing
# Motor Vehicles & Parts                          Motor Vehicles and Parts
# Retailing                                     Specialty Retailers: Other
# Technology                    Network and Other Communications Equipment
# Telecommunications                                    Telecommunications
# Transportation                              Transportation and Logistics
# Wholesalers                                     Wholesalers: Diversified
#
#                                        Location  Revenue  Profits  Employees
# Sector
# Aerospace & Defense                  McLean, VA     1923     -133      12000
# Apparel                         Los Angeles, CA     2204       82      13500
# Business Services             Downers Grove, IL     1910      140      11770
# Chemicals                          St. Paul, MN     2084       87       4425
# Energy                             Portland, OR     1898      172       2646
# Engineering & Construction           Denver, CO     1909       66       1225
# Financials                         Westbury, NY     1902      -47       3448
# Food and Drug Stores                Memphis, TN     2151       -7       7103
# Food, Beverages & Tobacco       Morrisville, NC     2066      -15       6835
# Health Care                          Tucson, AZ     1987       84       9072
# Hotels, Resturants & Leisure         Dublin, OH     1896      161      21200
# Household Products                 New York, NY     1914       56       5700
# Industrials                       Wauwatosa, WI     1895       46       5480
# Materials                          Portland, OR     1924     -197       2955
# Media                              Stamford, CT     1921      -31       7300
# Motor Vehicles & Parts         Indianaoplis, IN     1986      182       2700
# Retailing                          Commerce, CA     1999     -232      18200
# Technology                          Seattle, WA     1920      365       4178
# Telecommunications             Redwood City, CA     2726      188       5042
# Transportation                       Cudahy, WI     1995       48       4502
# Wholesalers                         Atlanta, GA     1917      -12       1600

# %% [markdown]
# ## 2. Retrieve a Group with the `get_group` Method
#
# - The `get_group` method on the **DataFrameGroupBy** object retrieves a nested **DataFrame** belonging to a specific group/category.

# %%
# load dataset

fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")

fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
# method to retrieve Df/group within DataFrameGroupBy Object
sectors.get_group("Technology")
sectors.get_group("Retailing")
sectors.get_group("Energy")
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#              Location  Revenue  Profits  Employees
# Rank
# 2          Irving, TX   246204    16150      75600
# 14      San Ramon, CA   131118     4587      61500
# 30        Houston, TX    87169     4227      14000
# 32    San Antonio, TX    81824     3990      10103
# 42        Findlay, OH    64566     2852      45440
# ...               ...      ...      ...        ...
# 981         Tulsa, OK     1958    -1727       1040
# 983       Houston, TX     1944       -1        809
# 995       Houston, TX     1908    -3748        665
# 997      Portland, OR     1898      172       2646
# 997      Portland, OR     1898      172       2646
#
# [122 rows x 7 columns]

# %% [markdown]
# ## 3. Methods on the GroupBy Object
#
# - Use square brackets on the **DataFrameGroupBy** object to *"extract" a column* from the original **DataFrame**.
# - The resulting **SeriesGroupBy** object will have aggregation methods available on it.
# - Pandas will perform the calculation *on every group* within the collection.
# - For example, the `sum` method will sum together the **Revenue** for every row by group/category.

# %%
# load dataset

fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")

fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
sectors["Revenue"] # extract 1 column from DataFrameGroupBy Object = we get back a SeriesGroupBy object

# %%
# on this SeriesGroupBy object we can perform multiple aggregation methods
fortune.groupby("Sector")["Revenue"].sum() # simply indicate what column to group on, subset Revenue column, apply sum() method
# or with the sectors-variable notation:
sectors["Revenue"].sum()
# Out:
# Sector
# Aerospace & Defense              357940
# Apparel                           95968
# Business Services                272195
# Chemicals                        243897
# Energy                          1517809
# Engineering & Construction       153983
# Financials                      2217159
# Food and Drug Stores             483769
# Food, Beverages & Tobacco        555967
# Health Care                     1614707
# Hotels, Resturants & Leisure     169546
# Household Products               234737
# Industrials                      497581
# Materials                        259145
# Media                            220764
# Motor Vehicles & Parts           482540
# Retailing                       1465076
# Technology                      1377600
# Telecommunications               461834
# Transportation                   408508
# Wholesalers                      444800
# Name: Revenue, dtype: int64

# %%
# other methods:
sectors["Revenue"].max()
sectors["Revenue"].min()
sectors["Revenue"].mean()
# Out:
# Sector
# Aerospace & Defense             17897.000000
# Apparel                          6397.866667
# Business Services                5337.156863
# Chemicals                        8129.900000
# Energy                          12441.057377
# Engineering & Construction       5922.423077
# Financials                      15950.784173
# Food and Drug Stores            32251.266667
# Food, Beverages & Tobacco       12929.465116
# Health Care                     21529.426667
# Hotels, Resturants & Leisure     6781.840000
# Household Products               8383.464286
# Industrials                     10816.978261
# Materials                        6026.627907
# Media                            8830.560000
# Motor Vehicles & Parts          20105.833333
# Retailing                       18313.450000
# Technology                      13505.882353
# Telecommunications              30788.933333
# Transportation                  11347.444444
# Wholesalers                     11120.000000
# Name: Revenue, dtype: float64

# %% [markdown]
# ## 4. Grouping by Multiple Columns
#
# - Pass a list of columns to the `groupby` method to group by combination of values across columns.
# - Target a column to retrieve the **SeriesGroupBy** object, then perform an aggregation with a method.
# - Pandas will return a **MultiIndex Series** where the levels will be the original groups.

# %%
# load dataset

fortune = pd.read_csv("fortune1000.csv", index_col="Rank")

fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
# make groups based on combination of values accross multiple datasets

# example: Industry column is subtype of Sector column
# for every of these combined groups Pandas will then perform aggregation

sectors_annex_industries = fortune.groupby(["Sector","Industry"])
sectors_annex_industries.size() # for every 79 unique combis we get a separate grouping
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            20
# Apparel              Apparel                                          15
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         3
#                                                                       ..
# Transportation       Trucking, Truck Leasing                           9
# Wholesalers          Miscellaneous                                     1
#                      Wholesalers: Diversified                         25
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
# Length: 79, dtype: int64

# %%
sectors_annex_industries["Revenue"].sum() # we can again target a column for which we want to perform aggregation & call method on it
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            357940
# Apparel              Apparel                                           95968
# Business Services    Advertising, marketing                            22748
#                      Diversified Outsourcing Services                  64829
#                      Education                                          7485
#                                                                        ...
# Transportation       Trucking, Truck Leasing                           35950
# Wholesalers          Miscellaneous                                      8982
#                      Wholesalers: Diversified                         176138
#                      Wholesalers: Electronics and Office Equipment    147906
#                      Wholesalers: Food and Grocery                    111774
# Name: Revenue, Length: 79, dtype: int64

# %% [markdown]
# ## 5. The `agg` Method
#
# - The `agg` method applies different aggregation methods on different columns.
# - Invoke the `agg` method directly on the **DataFrameGroupBy** object.
# - Pass the method a dictionary where the keys are the columns and the values are the aggregation operations.

# %%
# load dataset

fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")

fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
# allows to do different operations on different groups

sectors.agg({"Revenue":"sum","Profits":"max"}) # apply .agg() method directly on DataFrameGroupBy Object
# Out:
#                               Revenue  Profits
# Sector
# Aerospace & Defense            357940     7608
# Apparel                         95968     3273
# Business Services              272195     6328
# Chemicals                      243897     7685
# Energy                        1517809    16150
# Engineering & Construction     153983      803
# Financials                    2217159    24442
# Food and Drug Stores           483769     5237
# Food, Beverages & Tobacco      555967     7351
# Health Care                   1614707    18108
# Hotels, Resturants & Leisure   169546     5920
# Household Products             234737     7036
# Industrials                    497581     4833
# Materials                      259145      991
# Media                          220764     8382
# Motor Vehicles & Parts         482540     9687
# Retailing                     1465076    14694
# Technology                    1377600    53394
# Telecommunications             461834    17879
# Transportation                 408508     7610
# Wholesalers                    444800     1472

# %% [markdown]
# ## 6. Iterating through Groups with `.apply()` method
#
# - The **DataFrameGroupBy** object supports the `apply` method (just like a **Series** and a **DataFrame** do).
# - The `apply` method invokes a function on every nested **DataFrame** in the **DataFrameGroupBy** object.
# - It captures the return values of the functions and collects them in a new **DataFrame** (the return value).

# %%
# load dataset

fortune = pd.read_csv("fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")

fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
# with Series Object .apply() method invokes function once for every value
# with DataFrame Object .apply() method invokes function once for every row
# with DataDrameGrouby Object .apply() method invokes function once for every group/nested Df in DataFrameGroupby Object

# Example: find 2 companies in every sector with most employees

fortune.nlargest(2,"Employees") # this only works on the whole of the Dataset
# Out:
#          Company                        Sector               Industry  \
# Rank
# 1        Walmart                     Retailing  General Merchandisers
# 218   Yum Brands  Hotels, Resturants & Leisure          Food Services
#
#              Location  Revenue  Profits  Employees
# Rank
# 1     Bentonville, AR   482130    14694    2300000
# 218    Louisville, KY    13105     1293     505000

# %%
def top_two_companies_by_employee_count(sector):
    return sector.nlargest(2,"Employees")

sectors.apply(top_two_companies_by_employee_count) # will apply function 21 times for every nested Df
# Out:
# /var/folders/p_/7g1rh2d11bv7z35m9lmpfxnm0000gn/T/ipykernel_25121/2566106824.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sectors.apply(top_two_companies_by_employee_count) # will apply function 21 times for every nested Df
#                                                     Company  \
# Sector                       Rank
# Aerospace & Defense          45         United Technologies
#                              24                      Boeing
# Apparel                      448                Hanesbrands
#                              231                         VF
# Business Services            199                    Aramark
#                              744                  Convergys
# Chemicals                    101                     DuPont
#                              56                Dow Chemical
# Energy                       2                  Exxon Mobil
#                              117                Halliburton
# Engineering & Construction   156                      AECOM
#                              235   Jacobs Engineering Group
# Financials                   4           Berkshire Hathaway
#                              27                 Wells Fargo
# Food and Drug Stores         17                      Kroger
#                              19    Walgreens Boots Alliance
# Food, Beverages & Tobacco    44                     PepsiCo
#                              62                   Coca-Cola
# Health Care                  63                HCA Holdings
#                              6           UnitedHealth Group
# Hotels, Resturants & Leisure 218                 Yum Brands
#                              109                 McDonald’s
# Household Products           34            Procter & Gamble
#                              256     Stanley Black & Decker
# Industrials                  11            General Electric
#                              75     Honeywell International
# Materials                    126                      Alcoa
#                              127        International Paper
# Media                        53                      Disney
#                              255      R.R. Donnelley & Sons
# Motor Vehicles & Parts       8               General Motors
#                              9                   Ford Motor
# Retailing                    1                      Walmart
#                              28                  Home Depot
# Technology                   31                         IBM
#                              20                          HP
# Telecommunications           10                        AT&T
#                              13                     Verizon
# Transportation               48                         UPS
#                              58                       FedEx
# Wholesalers                  212                     Synnex
#                              57                       Sysco
#
#                                                          Sector  \
# Sector                       Rank
# Aerospace & Defense          45             Aerospace & Defense
#                              24             Aerospace & Defense
# Apparel                      448                        Apparel
#                              231                        Apparel
# Business Services            199              Business Services
#                              744              Business Services
# Chemicals                    101                      Chemicals
#                              56                       Chemicals
# Energy                       2                           Energy
#                              117                         Energy
# Engineering & Construction   156     Engineering & Construction
#                              235     Engineering & Construction
# Financials                   4                       Financials
#                              27                      Financials
# Food and Drug Stores         17            Food and Drug Stores
#                              19            Food and Drug Stores
# Food, Beverages & Tobacco    44       Food, Beverages & Tobacco
#                              62       Food, Beverages & Tobacco
# Health Care                  63                     Health Care
#                              6                      Health Care
# Hotels, Resturants & Leisure 218   Hotels, Resturants & Leisure
#                              109   Hotels, Resturants & Leisure
# Household Products           34              Household Products
#                              256             Household Products
# Industrials                  11                     Industrials
#                              75                     Industrials
# Materials                    126                      Materials
#                              127                      Materials
# Media                        53                           Media
#                              255                          Media
# Motor Vehicles & Parts       8           Motor Vehicles & Parts
#                              9           Motor Vehicles & Parts
# Retailing                    1                        Retailing
#                              28                       Retailing
# Technology                   31                      Technology
#                              20                      Technology
# Telecommunications           10              Telecommunications
#                              13              Telecommunications
# Transportation               48                  Transportation
#                              58                  Transportation
# Wholesalers                  212                    Wholesalers
#                              57                     Wholesalers
#
#                                                                         Industry  \
# Sector                       Rank
# Aerospace & Defense          45                            Aerospace and Defense
#                              24                            Aerospace and Defense
# Apparel                      448                                         Apparel
#                              231                                         Apparel
# Business Services            199                Diversified Outsourcing Services
#                              744                Diversified Outsourcing Services
# Chemicals                    101                                       Chemicals
#                              56                                        Chemicals
# Energy                       2                                Petroleum Refining
#                              117                 Oil and Gas Equipment, Services
# Engineering & Construction   156                       Engineering, Construction
#                              235                       Engineering, Construction
# Financials                   4          Insurance: Property and Casualty (Stock)
#                              27                                 Commercial Banks
# Food and Drug Stores         17                             Food and Drug Stores
#                              19                             Food and Drug Stores
# Food, Beverages & Tobacco    44                           Food Consumer Products
#                              62                                        Beverages
# Health Care                  63                  Health Care: Medical Facilities
#                              6           Health Care: Insurance and Managed Care
# Hotels, Resturants & Leisure 218                                   Food Services
#                              109                                   Food Services
# Household Products           34                  Household and Personal Products
#                              256                     Home Equipment, Furnishings
# Industrials                  11                             Industrial Machinery
#                              75                   Electronics, Electrical Equip.
# Materials                    126                                          Metals
#                              127                           Packaging, Containers
# Media                        53                                    Entertainment
#                              255                            Publishing, Printing
# Motor Vehicles & Parts       8                          Motor Vehicles and Parts
#                              9                          Motor Vehicles and Parts
# Retailing                    1                             General Merchandisers
#                              28                       Specialty Retailers: Other
# Technology                   31                  Information Technology Services
#                              20                      Computers, Office Equipment
# Telecommunications           10                               Telecommunications
#                              13                               Telecommunications
# Transportation               48              Mail, Package, and Freight Delivery
#                              58              Mail, Package, and Freight Delivery
# Wholesalers                  212   Wholesalers: Electronics and Office Equipment
#                              57                    Wholesalers: Food and Grocery
#
#                                             Location  Revenue  Profits  \
# Sector                       Rank
# Aerospace & Defense          45       Farmington, CT    61047     7608
#                              24          Chicago, IL    96114     5176
# Apparel                      448   Winston-Salem, NC     5732      429
#                              231      Greensboro, NC    12377     1232
# Business Services            199    Philadelphia, PA    14329      236
#                              744      Cincinnati, OH     2951      169
# Chemicals                    101      Wilmington, DE    27940     1953
#                              56          Midland, MI    48778     7685
# Energy                       2            Irving, TX   246204    16150
#                              117         Houston, TX    23633     -671
# Engineering & Construction   156     Los Angeles, CA    17990     -155
#                              235        Pasadena, CA    12115      303
# Financials                   4             Omaha, NE   210821    24083
#                              27    San Francisco, CA    90033    22894
# Food and Drug Stores         17       Cincinnati, OH   109830     2039
#                              19        Deerfield, IL   103444     4220
# Food, Beverages & Tobacco    44         Purchase, NY    63056     5452
#                              62          Atlanta, GA    44294     7351
# Health Care                  63        Nashville, TN    43591     2129
#                              6        Minnetonka, MN   157107     5813
# Hotels, Resturants & Leisure 218      Louisville, KY    13105     1293
#                              109       Oak Brook, IL    25413     4529
# Household Products           34       Cincinnati, OH    78756     7036
#                              256     New Britain, CT    11211      884
# Industrials                  11        Fairfield, CT   140389    -6126
#                              75    Morris Plains, NJ    38581     4768
# Materials                    126        New York, NY    22534     -322
#                              127         Memphis, TN    22365      938
# Media                        53          Burbank, CA    52465     8382
#                              255         Chicago, IL    11257      151
# Motor Vehicles & Parts       8           Detroit, MI   152356     9687
#                              9          Dearborn, MI   149558     7373
# Retailing                    1       Bentonville, AR   482130    14694
#                              28          Atlanta, GA    88519     7009
# Technology                   31           Armonk, NY    82461    13190
#                              20        Palo Alto, CA   103355     4554
# Telecommunications           10           Dallas, TX   146801    13345
#                              13         New York, NY   131620    17879
# Transportation               48          Atlanta, GA    58363     4844
#                              58          Memphis, TN    47453     1050
# Wholesalers                  212         Fremont, CA    13338      209
#                              57          Houston, TX    48681      687
#
#                                    Employees
# Sector                       Rank
# Aerospace & Defense          45       197200
#                              24       161400
# Apparel                      448       65300
#                              231       64000
# Business Services            199      216500
#                              744      130000
# Chemicals                    101       52000
#                              56        49495
# Energy                       2         75600
#                              117       65000
# Engineering & Construction   156       92000
#                              235       56950
# Financials                   4        331000
#                              27       264700
# Food and Drug Stores         17       431000
#                              19       302500
# Food, Beverages & Tobacco    44       263000
#                              62       123200
# Health Care                  63       203500
#                              6        200000
# Hotels, Resturants & Leisure 218      505000
#                              109      420000
# Household Products           34       110000
#                              256       51250
# Industrials                  11       333000
#                              75       129000
# Materials                    126       60000
#                              127       56000
# Media                        53       185000
#                              255       68400
# Motor Vehicles & Parts       8        215000
#                              9        199000
# Retailing                    1       2300000
#                              28       385000
# Technology                   31       411798
#                              20       287000
# Telecommunications           10       281450
#                              13       177700
# Transportation               48       341240
#                              58       323035
# Wholesalers                  212       78500
#                              57        51700
